# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("data.csv")
print(df)
# Out:
#   sample  value
# 0     S1   12.5
# 1     S2   15.1
# 2     S3   13.2

# %%
print("المتوسط:",df["value"].mean())
print("الانحراف المعياري:", df["value"].std())
# Out:
# المتوسط: 13.6
# الانحراف المعياري: 1.345362404707371

# %%
import matplotlib.pyplot as plt
df.plot(kind='bar', x='sample', y='value', title='قيم العينات')
plt.show()
